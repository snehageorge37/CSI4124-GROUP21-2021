# %%
import pandas as pd
import numpy as np

from datetime import datetime, timedelta

# %%
dailydata = pd.read_csv("conposcovidloc.csv")
dailydata.head()
# Out:
#    Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 0       1            2020-06-06         2020-06-12         2020-06-11
# 1       2            2020-05-03         2020-05-11         2020-05-11
# 2       3            2020-04-16         2020-04-19         2020-04-19
# 3       4            2020-04-07         2020-04-26         2020-04-26
# 4       5            2020-05-21         2020-05-22         2020-05-22
#
#   Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  Outcome1  \
# 0    2020-06-10       50s        FEMALE                   CC  Resolved
# 1    2020-05-10       70s          MALE                   OB     Fatal
# 2    2020-04-17       40s        FEMALE                   OB  Resolved
# 3    2020-04-21       60s          MALE                   CC  Resolved
# 4    2020-05-21       60s        FEMALE                   OB  Resolved
#
#   Outbreak_Related  Reporting_PHU_ID                    Reporting_PHU  \
# ...

# %%
dailydata.shape
# Out:
# (289621, 18)

# %%
dailydata.columns
# Out:
# Index(['Row_ID', 'Accurate_Episode_Date', 'Case_Reported_Date',
#        'Test_Reported_Date', 'Specimen_Date', 'Age_Group', 'Client_Gender',
#        'Case_AcquisitionInfo', 'Outcome1', 'Outbreak_Related',
#        'Reporting_PHU_ID', 'Reporting_PHU', 'Reporting_PHU_Address',
#        'Reporting_PHU_City', 'Reporting_PHU_Postal_Code',
#        'Reporting_PHU_Website', 'Reporting_PHU_Latitude',
#        'Reporting_PHU_Longitude'],
#       dtype='object')

# %%
dailydata = dailydata.drop(['Accurate_Episode_Date', 'Case_Reported_Date', 'Test_Reported_Date', 'Specimen_Date', 'Age_Group', 'Client_Gender', 'Case_AcquisitionInfo', 'Outcome1', 'Outbreak_Related', 'Reporting_PHU_Website'], axis=1)

# %%
dailydata.columns
# Out:
# Index(['Row_ID', 'Reporting_PHU_ID', 'Reporting_PHU', 'Reporting_PHU_Address',
#        'Reporting_PHU_City', 'Reporting_PHU_Postal_Code',
#        'Reporting_PHU_Latitude', 'Reporting_PHU_Longitude'],
#       dtype='object')

# %%
dailydata.head()
# Out:
#    Row_ID  Reporting_PHU_ID                    Reporting_PHU  \
# 0       1              2236  Halton Region Health Department
# 1       2              2253               Peel Public Health
# 2       3              2253               Peel Public Health
# 3       4              2253               Peel Public Health
# 4       5              2253               Peel Public Health
#
#     Reporting_PHU_Address Reporting_PHU_City Reporting_PHU_Postal_Code  \
# 0        1151 Bronte Road           Oakville                   L6M 3Ll
# 1  7120 Hurontario Street        Mississauga                   L5W 1N4
# 2  7120 Hurontario Street        Mississauga                   L5W 1N4
# 3  7120 Hurontario Street        Mississauga                   L5W 1N4
# 4  7120 Hurontario Street        Mississauga                   L5W 1N4
#
#    Reporting_PHU_Latitude  Reporting_PHU_Longitude
# 0               43.413997               -79.744796
# 1               43.647471               -79.708893
# ...

# %%
removeCities = dailydata[(dailydata['Reporting_PHU_City'] != 'Toronto') & (dailydata['Reporting_PHU_City'] != 'Ottawa')].index
dailydata.drop(removeCities , inplace=True)

# %%
dailydata.head()
# Out:
#      Row_ID  Reporting_PHU_ID          Reporting_PHU  \
# 249     250              3895  Toronto Public Health
# 258     259              3895  Toronto Public Health
# 321     322              3895  Toronto Public Health
# 325     326              3895  Toronto Public Health
# 346     347              3895  Toronto Public Health
#
#               Reporting_PHU_Address Reporting_PHU_City  \
# 249  277 Victoria Street, 5th Floor            Toronto
# 258  277 Victoria Street, 5th Floor            Toronto
# 321  277 Victoria Street, 5th Floor            Toronto
# 325  277 Victoria Street, 5th Floor            Toronto
# 346  277 Victoria Street, 5th Floor            Toronto
#
#     Reporting_PHU_Postal_Code  Reporting_PHU_Latitude  Reporting_PHU_Longitude
# 249                   M5B 1W2               43.656591               -79.379358
# 258                   M5B 1W2               43.656591               -79.379358
# ...

# %%
dailydata = dailydata.drop(['Row_ID'], axis=1)

# %%
dailydata = dailydata.drop_duplicates()

# %%
dailydata
# Out:
#       Reporting_PHU_ID          Reporting_PHU           Reporting_PHU_Address  \
# 249               3895  Toronto Public Health  277 Victoria Street, 5th Floor
# 8095              2251   Ottawa Public Health         100 Constellation Drive
#
#      Reporting_PHU_City Reporting_PHU_Postal_Code  Reporting_PHU_Latitude  \
# 249             Toronto                   M5B 1W2               43.656591
# 8095             Ottawa                   K2G 6J8               45.345665
#
#       Reporting_PHU_Longitude
# 249                -79.379358
# 8095               -75.763912

# %%
dailydata.insert(len(dailydata.columns), "surrogate_key",  np.arange(len(dailydata)))

# %%
dailydata
# Out:
#       Reporting_PHU_ID          Reporting_PHU           Reporting_PHU_Address  \
# 249               3895  Toronto Public Health  277 Victoria Street, 5th Floor
# 8095              2251   Ottawa Public Health         100 Constellation Drive
#
#      Reporting_PHU_City Reporting_PHU_Postal_Code  Reporting_PHU_Latitude  \
# 249             Toronto                   M5B 1W2               43.656591
# 8095             Ottawa                   K2G 6J8               45.345665
#
#       Reporting_PHU_Longitude  surrogate_key
# 249                -79.379358              0
# 8095               -75.763912              1

# %%
dailydata.to_csv("PHU_location_dimension.csv",index=False)
