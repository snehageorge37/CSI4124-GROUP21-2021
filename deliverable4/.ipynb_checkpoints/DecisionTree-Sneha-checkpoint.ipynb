# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score
import psycopg2
from collections import Counter

# %%
table_cols = [('age_group', 'reporting_phu_city', 'cause_of_infection', 'gender', 'Resolved', 'Fatal', 'Special_Measure_Key')]
fact_table = []

def connect():
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        return psycopg2.connect(
            host="www.eecs.uottawa.ca",
            database="group_21",
            user="****",
            password="****",
            port="15432"
        )
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)


connection = connect()
print('***Connection established***')

cur = connection.cursor()
        
cur.execute('SELECT I.age_group, I.reporting_phu_city,\
            I.cause_of_infection, I.gender, F."Resolved",\
            F."Fatal", F."Special_Measure_Key" FROM fact_table_v2 as F\
            INNER JOIN individuals as I on I.individual_id = F."Individual_Key"')
rows = cur.fetchall()
fact_table = rows
print(fact_table[:10])

cur.close()
connection.close()
print('***Connection terminated***')
# Out:
# Connecting to the PostgreSQL database...
# ***Connection established***
# [('40s', 'Toronto', 'OB', 'FEMALE', 'yes', 'no', 11), ('30s', 'Toronto', 'OB', 'FEMALE', 'yes', 'no', 11), ('90+', 'Toronto', 'OB', 'FEMALE', 'no', 'yes', 11), ('80s', 'Toronto', 'OB', 'FEMALE', 'yes', 'no', 11), ('50s', 'Toronto', 'OB', 'FEMALE', 'yes', 'no', 11), ('30s', 'Toronto', 'OB', 'FEMALE', 'yes', 'no', 11), ('50s', 'Toronto', 'OB', 'FEMALE', 'yes', 'no', 11), ('50s', 'Toronto', 'OB', 'MALE', 'yes', 'no', 11), ('20s', 'Toronto', 'OB', 'FEMALE', 'yes', 'no', 11), ('80s', 'Toronto', 'NO KNOWN EPI LINK', 'FEMALE', 'yes', 'no', 2)]
# ***Connection terminated***

# %%
result_df = pd.DataFrame(fact_table, columns=["age_group", "reporting_phu_city", "cause_of_infection", 
                                               "gender", "Resolved","Fatal","Special_Measure_Key"])
#result_df.head()

# %% [markdown]
# ### One Hot Encoding
# ##### Class = Age Group
# - create 9 columns with boolean values and check for imbalance
# - one hot encoding to turn into 0s and 1s and then more preprocessing to convert those to boolean values
#
# ##### Features
# - City, Cause of Infection, Gender, Resolved, Fatal, Special Measures

# %%
new_result_df = pd.get_dummies(result_df, prefix=["age_group", "reporting_phu_city", "cause_of_infection", "gender", "Resolved", "Fatal"])
X = new_result_df.values
#new_result_df.head()

# %% [markdown]
# Special Measures is a bit more complicated so need to do some more processing. Using the sklearn library to handle the complications.

# %%
# Create Labeler and Encoder
labelencoder = LabelEncoder()
encoder = OneHotEncoder(dtype=int, handle_unknown='ignore')

# %%
# Assigning numerical values and storing in another column
new_result_df['Special_Measure_Key_Tmp'] = labelencoder.fit_transform(new_result_df['Special_Measure_Key'])
#new_result_df.head()

# %%
# passing bridge-types-cat column (label encoded values of bridge_types)
enc_df = pd.DataFrame(encoder.fit_transform(new_result_df[['Special_Measure_Key_Tmp']]).toarray())

# %%
#  merge with main df bridge_df on key values
new_result_df = new_result_df.join(enc_df)
new_result_df.rename(columns={6: "lockdown", 10: "stage 3 extended to toronto", 2: "Restart", 1: "Gatineau-Ottawa Travel Restriction", 3: "Parks Re-opened"},inplace = True)
new_result_df = new_result_df.drop(['Special_Measure_Key_Tmp'], axis=1)
#new_result_df.head()

# %%
new_result_df = new_result_df.drop(['Special_Measure_Key', 4, 5], axis=1)
#new_result_df.head()

# %% [markdown]
# ### Undersampling

# %%
from collections import Counter 
Counter(new_result_df['age_group_20s'])
# Out:
# Counter({0: 13125, 1: 2131})

# %%
Counter(new_result_df['age_group_30s'])
# Out:
# Counter({0: 13219, 1: 2037})

# %%
Counter(new_result_df['age_group_40s'])
# Out:
# Counter({1: 2107, 0: 13149})

# %%
Counter(new_result_df['age_group_50s'])
# Out:
# Counter({0: 12859, 1: 2397})

# %%
Counter(new_result_df['age_group_60s'])
# Out:
# Counter({0: 13612, 1: 1644})

# %%
Counter(new_result_df['age_group_70s'])
# Out:
# Counter({0: 14135, 1: 1121})

# %%
Counter(new_result_df['age_group_80s'])
# Out:
# Counter({0: 13569, 1: 1687})

# %%
Counter(new_result_df['age_group_90+'])
# Out:
# Counter({0: 13973, 1: 1283})

# %%
Counter(new_result_df['age_group_<20'])
# Out:
# Counter({0: 14408, 1: 848})

# %% [markdown]
# All classes are highly imbalanced. It's even more clear by plotting 'age group 20s'.

# %%
import matplotlib.pyplot as plt

labels = 'True', 'False'
sizes = [13125, 2131]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')

#plt.show()
# Out:
# (-1.1067402961074844,
#  1.1022251644441523,
#  -1.1065996248296672,
#  1.1003142678490319)

# %% [markdown]
# Therefore, it is likely if we train our model to classify 'age group 20s' on this dataset, during testing it will more often than not predict false.

# %%
from sklearn.utils import resample

df_majority = new_result_df[new_result_df.age_group_20s==False]
df_minority = new_result_df[new_result_df.age_group_20s==True]

df_majority_upsampled = resample(df_majority, 
                                 replace=True,     # sample with replacement
                                 n_samples=2131,    # to match minority class
                                 random_state=42)

df_upsampled = pd.concat([df_minority, df_majority_upsampled])

#df_upsampled.age_group_20s.value_counts()

# %%
# put undersampling into function
def undersample(column_name):
  df_majority = new_result_df[new_result_df[column_name]==False]
  df_minority = new_result_df[new_result_df[column_name]==True]

  df_majority_upsampled = resample(df_majority, 
                                  replace=True,     # sample with replacement
                                  n_samples=len(df_minority.index),    # to match minority class
                                  random_state=42)

  df_upsampled = pd.concat([df_minority, df_majority_upsampled])

  print(df_upsampled[column_name].value_counts())

  return df_upsampled

# %%
df_age_group_30s = undersample("age_group_30s")
df_age_group_40s = undersample("age_group_40s")
df_age_group_50s = undersample("age_group_50s")
df_age_group_60s = undersample("age_group_60s")
df_age_group_70s = undersample("age_group_70s")
df_age_group_80s = undersample("age_group_80s")
df_age_group_90s = undersample("age_group_90+")
df_age_group_20s = undersample("age_group_<20")
# Out:
# 1    2037
# 0    2037
# Name: age_group_30s, dtype: int64
# 1    2107
# 0    2107
# Name: age_group_40s, dtype: int64
# 1    2397
# 0    2397
# Name: age_group_50s, dtype: int64
# 1    1644
# 0    1644
# Name: age_group_60s, dtype: int64
# 1    1121
# 0    1121
# Name: age_group_70s, dtype: int64
# 1    1687
# 0    1687
# Name: age_group_80s, dtype: int64
# 1    1283
# 0    1283
# Name: age_group_90+, dtype: int64
# 1    848
# 0    848
# Name: age_group_<20, dtype: int64

# %%
df_age_group_20s.drop(['age_group_30s', 'age_group_40s', 'age_group_50s', 'age_group_60s', 'age_group_70s', 'age_group_80s', 'age_group_90+','age_group_<20', 'age_group_UNKNOWN', 0], axis=1, inplace=True)

# %% [markdown]
# ### We are done with pre-processing of our data. Next, we need to divide our data to training and testing sets.

# %%
#Get the labels
y = df_age_group_20s['age_group_20s']
df_age_group_20s.drop(['age_group_20s'], axis=1, inplace=True)
X = df_age_group_20s.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, stratify=y)
#Let's see the no. of records per class in training and test set
print("Training set {} ".format(Counter(y_train)))
print("Test set {} ".format(Counter(y_test)))
# Out:
# Training set Counter({0: 1042, 1: 94})
# Test set Counter({0: 514, 1: 46})

# %% [markdown]
# ## Now let us apply the DecisionTreeClassifier algorithm

# %%
#This step is to train our classifier based on the training data.
dt = DecisionTreeClassifier(criterion='entropy')
import time
t0= time.perf_counter()
dt.fit(X_train, y_train)
t1 = time.perf_counter() - t0
print("Accuracy score (training): {0:.3f}".format(dt.score(X_train, y_train)))
print("Accuracy score (testing): {0:.3f}".format(dt.score(X_test, y_test)))
print("Time to construct model ", t1)

from sklearn.metrics import classification_report
predictions = dt.predict(X_test)
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Accuracy score (training): 0.918
# Accuracy score (testing): 0.916
# Time to construct model  0.004062916999999722
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       514
#            1       0.40      0.04      0.08        46
#
#     accuracy                           0.92       560
#    macro avg       0.66      0.52      0.52       560
# weighted avg       0.88      0.92      0.88       560

# %%
r = export_text(dt, feature_names=df_age_group_20s.columns.values.tolist())
print(r)
# Out:
# |--- Fatal_yes <= 0.50
# |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |--- Restart <= 0.50
# |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- Restart >  0.50
# |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- lockdown >  0.50
# |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- Parks Re-opened >  0.50
# |   |   |   |--- class: 0
# |--- Fatal_yes >  0.50
# |   |--- class: 0

# %% [markdown]
# ### Apply to 30s

# %%
df_age_group_30s.drop(['age_group_20s','age_group_40s', 'age_group_50s', 'age_group_60s', 'age_group_70s', 'age_group_80s', 'age_group_90+','age_group_<20', 'age_group_UNKNOWN',0], axis=1, inplace=True)

# %%
#Get the labels
y = df_age_group_30s['age_group_30s']
df_age_group_30s.drop(['age_group_30s'], axis=1, inplace=True)
X = df_age_group_30s.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, stratify=y)
#Let's see the no. of records per class in training and test set
print("Training set {} ".format(Counter(y_train)))
print("Test set {} ".format(Counter(y_test)))
# Out:
# Training set Counter({0: 1365, 1: 1364})
# Test set Counter({1: 673, 0: 672})

# %%
#This step is to train our classifier based on the training data.
dt = DecisionTreeClassifier(criterion='entropy')

t0= time.perf_counter()
dt.fit(X_train, y_train)
t1 = time.perf_counter() - t0
print("Accuracy score (training): {0:.3f}".format(dt.score(X_train, y_train)))
print("Accuracy score (testing): {0:.3f}".format(dt.score(X_test, y_test)))
print("Time to construct model ", t1)

predictions = dt.predict(X_test)
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Accuracy score (training): 0.610
# Accuracy score (testing): 0.587
# Time to construct model  0.005744947000000167
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.61      0.48      0.54       672
#            1       0.57      0.69      0.63       673
#
#     accuracy                           0.59      1345
#    macro avg       0.59      0.59      0.58      1345
# weighted avg       0.59      0.59      0.58      1345

# %%
r = export_text(dt, feature_names = df_age_group_30s.columns.values.tolist())
print(r)
# Out:
# |--- Fatal_yes <= 0.50
# |   |--- cause_of_infection_OB <= 0.50
# |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |--- gender_GENDER DIVERSE <= 0.50
# |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_GENDER DIVERSE >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- cause_of_infection_OB >  0.50
# |   |   |--- gender_MALE <= 0.50
# |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- lockdown >  0.50
# |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- gender_MALE >  0.50
# |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- class: 1
# |--- Fatal_yes >  0.50
# |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |--- gender_MALE <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- gender_MALE >  0.50
# |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- lockdown >  0.50
# |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |--- class: 0
# |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |--- class: 0

# %% [markdown]
# ### Apply to 40s

# %%
df_age_group_40s.drop(['age_group_20s','age_group_30s','age_group_50s', 'age_group_60s', 'age_group_70s', 'age_group_80s', 'age_group_90+','age_group_<20', 'age_group_UNKNOWN',0], axis=1, inplace=True)

# %%
#Get the labels
y = df_age_group_40s['age_group_40s']
df_age_group_40s.drop(['age_group_40s'], axis=1, inplace=True)
X = df_age_group_40s.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, stratify=y)
#Let's see the no. of records per class in training and test set
print("Training set {} ".format(Counter(y_train)))
print("Test set {} ".format(Counter(y_test)))
# Out:
# Training set Counter({1: 1412, 0: 1411})
# Test set Counter({0: 696, 1: 695})

# %%
#This step is to train our classifier based on the training data.
dt = DecisionTreeClassifier(criterion='entropy')

t0= time.perf_counter()
dt.fit(X_train, y_train)
t1 = time.perf_counter() - t0
print("Accuracy score (training): {0:.3f}".format(dt.score(X_train, y_train)))
print("Accuracy score (testing): {0:.3f}".format(dt.score(X_test, y_test)))
print("Time to construct model ", t1)

predictions = dt.predict(X_test)
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Accuracy score (training): 0.587
# Accuracy score (testing): 0.541
# Time to construct model  0.005047522999999998
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.54      0.55      0.55       696
#            1       0.54      0.53      0.54       695
#
#     accuracy                           0.54      1391
#    macro avg       0.54      0.54      0.54      1391
# weighted avg       0.54      0.54      0.54      1391

# %%
r = export_text(dt, feature_names = df_age_group_40s.columns.values.tolist())
print(r)
# Out:
# |--- Resolved_yes <= 0.50
# |   |--- cause_of_infection_OB <= 0.50
# |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- Parks Re-opened >  0.50
# |   |   |   |--- class: 1
# |   |--- cause_of_infection_OB >  0.50
# |   |   |--- gender_MALE <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- gender_MALE >  0.50
# |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |--- class: 0
# |--- Resolved_yes >  0.50
# |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- lockdown >  0.50
# |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |--- class: 1
# |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- Parks Re-opened >  0.50
# |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |--- class: 1

# %% [markdown]
# ### Age group 50s

# %%
df_age_group_50s.drop(['age_group_20s','age_group_30s','age_group_40s', 'age_group_60s', 'age_group_70s', 'age_group_80s', 'age_group_90+','age_group_<20', 'age_group_UNKNOWN',0], axis=1, inplace=True)
#Get the labels
y = df_age_group_50s['age_group_50s']
df_age_group_50s.drop(['age_group_50s'], axis=1, inplace=True)
X = df_age_group_50s.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, stratify=y)
#Let's see the no. of records per class in training and test set
print("Training set {} ".format(Counter(y_train)))
print("Test set {} ".format(Counter(y_test)))

#This step is to train our classifier based on the training data.
dt = DecisionTreeClassifier(criterion='entropy')

t0= time.perf_counter()
dt.fit(X_train, y_train)
t1 = time.perf_counter() - t0
print("Accuracy score (training): {0:.3f}".format(dt.score(X_train, y_train)))
print("Accuracy score (testing): {0:.3f}".format(dt.score(X_test, y_test)))
print("Time to construct model ", t1)

predictions = dt.predict(X_test)
print("Classification Report")
print(classification_report(y_test, predictions))

r = export_text(dt, feature_names = df_age_group_50s.columns.values.tolist())
print(r)
# Out:
# Training set Counter({1: 1606, 0: 1605})
# Test set Counter({0: 792, 1: 791})
# Accuracy score (training): 0.595
# Accuracy score (testing): 0.539
# Time to construct model  0.0054966190000005355
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      0.44      0.49       792
#            1       0.53      0.63      0.58       791
#
#     accuracy                           0.54      1583
#    macro avg       0.54      0.54      0.53      1583
# weighted avg       0.54      0.54      0.53      1583
#
# |--- Fatal_yes <= 0.50
# |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |--- gender_GENDER DIVERSE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- gender_GENDER DIVERSE >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |--- gender_GENDER DIVERSE <= 0.50
# |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_GENDER DIVERSE >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |--- class: 1
# |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- Parks Re-opened >  0.50
# |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |--- class: 0
# |--- Fatal_yes >  0.50
# |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- class: 1
# |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |--- class: 1

# %% [markdown]
# ### Age group 60s

# %%
df_age_group_60s.drop(['age_group_20s','age_group_30s','age_group_40s', 'age_group_50s', 'age_group_70s', 'age_group_80s', 'age_group_90+','age_group_<20', 'age_group_UNKNOWN',0], axis=1, inplace=True)
#Get the labels
y = df_age_group_60s['age_group_60s']
df_age_group_60s.drop(['age_group_60s'], axis=1, inplace=True)
X = df_age_group_60s.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, stratify=y)
#Let's see the no. of records per class in training and test set
print("Training set {} ".format(Counter(y_train)))
print("Test set {} ".format(Counter(y_test)))

#This step is to train our classifier based on the training data.
dt = DecisionTreeClassifier(criterion='entropy')

t0= time.perf_counter()
dt.fit(X_train, y_train)
t1 = time.perf_counter() - t0
print("Accuracy score (training): {0:.3f}".format(dt.score(X_train, y_train)))
print("Accuracy score (testing): {0:.3f}".format(dt.score(X_test, y_test)))
print("Time to construct model ", t1)

predictions = dt.predict(X_test)
print("Classification Report")
print(classification_report(y_test, predictions))

r = export_text(dt, feature_names = df_age_group_60s.columns.values.tolist())
print(r)
# Out:
# Training set Counter({1: 1101, 0: 1101})
# Test set Counter({0: 543, 1: 543})
# Accuracy score (training): 0.587
# Accuracy score (testing): 0.563
# Time to construct model  0.003311091000000488
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.56      0.58      0.57       543
#            1       0.57      0.54      0.55       543
#
#     accuracy                           0.56      1086
#    macro avg       0.56      0.56      0.56      1086
# weighted avg       0.56      0.56      0.56      1086
#
# |--- gender_MALE <= 0.50
# |   |--- Fatal_yes <= 0.50
# |   |   |--- lockdown <= 0.50
# |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- lockdown >  0.50
# |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |--- gender_GENDER DIVERSE <= 0.50
# |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_GENDER DIVERSE >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |--- class: 1
# |   |--- Fatal_yes >  0.50
# |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |--- class: 0
# |--- gender_MALE >  0.50
# |   |--- lockdown <= 0.50
# |   |   |--- Restart <= 0.50
# |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Resolved_yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Resolved_yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Resolved_no <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Resolved_no >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Resolved_yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- Resolved_yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |--- Fatal_yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Fatal_yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |--- Resolved_yes <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Resolved_yes >  0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |--- Fatal_yes <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Fatal_yes >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |--- Fatal_no <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Fatal_no >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- Fatal_no <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Fatal_no >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- Restart >  0.50
# |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |--- class: 0
# |   |--- lockdown >  0.50
# |   |   |--- Fatal_yes <= 0.50
# |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- Fatal_yes >  0.50
# |   |   |   |--- cause_of_infection_OB <= 0.50
# |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- cause_of_infection_OB >  0.50
# |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |--- class: 0

# %% [markdown]
# ### Age group 70s

# %%
df_age_group_70s.drop(['age_group_20s','age_group_30s','age_group_40s', 'age_group_50s', 'age_group_60s', 'age_group_80s', 'age_group_90+','age_group_<20', 'age_group_UNKNOWN',0], axis=1, inplace=True)
#Get the labels
y = df_age_group_70s['age_group_70s']
df_age_group_70s.drop(['age_group_70s'], axis=1, inplace=True)
X = df_age_group_70s.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, stratify=y)
#Let's see the no. of records per class in training and test set
print("Training set {} ".format(Counter(y_train)))
print("Test set {} ".format(Counter(y_test)))

#This step is to train our classifier based on the training data.
dt = DecisionTreeClassifier(criterion='entropy')

t0= time.perf_counter()
dt.fit(X_train, y_train)
t1 = time.perf_counter() - t0
print("Accuracy score (training): {0:.3f}".format(dt.score(X_train, y_train)))
print("Accuracy score (testing): {0:.3f}".format(dt.score(X_test, y_test)))
print("Time to construct model ", t1)

predictions = dt.predict(X_test)
print("Classification Report")
print(classification_report(y_test, predictions))

r = export_text(dt, feature_names = df_age_group_70s.columns.values.tolist())
print(r)
# Out:
# Training set Counter({1: 751, 0: 751})
# Test set Counter({1: 370, 0: 370})
# Accuracy score (training): 0.625
# Accuracy score (testing): 0.584
# Time to construct model  0.0030064740000002033
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.56      0.74      0.64       370
#            1       0.62      0.43      0.51       370
#
#     accuracy                           0.58       740
#    macro avg       0.59      0.58      0.57       740
# weighted avg       0.59      0.58      0.57       740
#
# |--- Resolved_yes <= 0.50
# |   |--- cause_of_infection_OB <= 0.50
# |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |--- class: 0
# |   |--- cause_of_infection_OB >  0.50
# |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- lockdown >  0.50
# |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |--- class: 1
# |--- Resolved_yes >  0.50
# |   |--- cause_of_infection_OB <= 0.50
# |   |   |--- lockdown <= 0.50
# |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- lockdown >  0.50
# |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |--- cause_of_infection_OB >  0.50
# |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- lockdown >  0.50
# |   |   |   |   |--- gender_GENDER DIVERSE <= 0.50
# |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_GENDER DIVERSE >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- gender_FEMALE >  0.50
# |   |   |   |--- Restart <= 0.50
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- Restart >  0.50
# |   |   |   |   |--- class: 0

# %% [markdown]
# ### Age group 80s

# %%
df_age_group_80s.drop(['age_group_20s','age_group_30s','age_group_40s', 'age_group_50s', 'age_group_60s', 'age_group_70s', 'age_group_90+','age_group_<20', 'age_group_UNKNOWN',0], axis=1, inplace=True)
#Get the labels
y = df_age_group_80s['age_group_80s']
df_age_group_80s.drop(['age_group_80s'], axis=1, inplace=True)
X = df_age_group_80s.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, stratify=y)
#Let's see the no. of records per class in training and test set
print("Training set {} ".format(Counter(y_train)))
print("Test set {} ".format(Counter(y_test)))

#This step is to train our classifier based on the training data.
dt = DecisionTreeClassifier(criterion='entropy')

t0= time.perf_counter()
dt.fit(X_train, y_train)
t1 = time.perf_counter() - t0
print("Accuracy score (training): {0:.3f}".format(dt.score(X_train, y_train)))
print("Accuracy score (testing): {0:.3f}".format(dt.score(X_test, y_test)))
print("Time to construct model ", t1)

predictions = dt.predict(X_test)
print("Classification Report")
print(classification_report(y_test, predictions))

r = export_text(dt, feature_names = df_age_group_80s.columns.values.tolist())
print(r)
# Out:
# Training set Counter({1: 1130, 0: 1130})
# Test set Counter({0: 557, 1: 557})
# Accuracy score (training): 0.750
# Accuracy score (testing): 0.743
# Time to construct model  0.0037878440000005398
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.64      0.71       557
#            1       0.70      0.85      0.77       557
#
#     accuracy                           0.74      1114
#    macro avg       0.75      0.74      0.74      1114
# weighted avg       0.75      0.74      0.74      1114
#
# |--- cause_of_infection_OB <= 0.50
# |   |--- Resolved_no <= 0.50
# |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- lockdown >  0.50
# |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- Resolved_no >  0.50
# |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |--- class: 1
# |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |--- class: 1
# |--- cause_of_infection_OB >  0.50
# |   |--- Resolved_yes <= 0.50
# |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- gender_FEMALE >  0.50
# |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |--- class: 0
# |   |--- Resolved_yes >  0.50
# |   |   |--- lockdown <= 0.50
# |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- lockdown >  0.50
# |   |   |   |--- gender_GENDER DIVERSE <= 0.50
# |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- gender_GENDER DIVERSE >  0.50
# |   |   |   |   |--- class: 0

# %% [markdown]
# ### Age group 90s

# %%
df_age_group_90s.drop(['age_group_20s','age_group_30s','age_group_40s', 'age_group_60s', 'age_group_70s', 'age_group_80s', 'age_group_50s','age_group_<20', 'age_group_UNKNOWN',0], axis=1, inplace=True)
#Get the labels
y = df_age_group_90s['age_group_90+']
df_age_group_90s.drop(['age_group_90+'], axis=1, inplace=True)
X = df_age_group_90s.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, stratify=y)
#Let's see the no. of records per class in training and test set
print("Training set {} ".format(Counter(y_train)))
print("Test set {} ".format(Counter(y_test)))

#This step is to train our classifier based on the training data.
dt = DecisionTreeClassifier(criterion='entropy')

t0= time.perf_counter()
dt.fit(X_train, y_train)
t1 = time.perf_counter() - t0
print("Accuracy score (training): {0:.3f}".format(dt.score(X_train, y_train)))
print("Accuracy score (testing): {0:.3f}".format(dt.score(X_test, y_test)))
print("Time to construct model ", t1)

predictions = dt.predict(X_test)
print("Classification Report")
print(classification_report(y_test, predictions))

r = export_text(dt, feature_names = df_age_group_90s.columns.values.tolist())
print(r)
# Out:
# Training set Counter({0: 860, 1: 859})
# Test set Counter({1: 424, 0: 423})
# Accuracy score (training): 0.804
# Accuracy score (testing): 0.789
# Time to construct model  0.0048672539999996545
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.67      0.76       423
#            1       0.73      0.91      0.81       424
#
#     accuracy                           0.79       847
#    macro avg       0.81      0.79      0.79       847
# weighted avg       0.81      0.79      0.79       847
#
# |--- cause_of_infection_OB <= 0.50
# |   |--- Resolved_yes <= 0.50
# |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |--- class: 0
# |   |--- Resolved_yes >  0.50
# |   |   |--- cause_of_infection_MISSING INFORMATION <= 0.50
# |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |--- cause_of_infection_TRAVEL <= 0.50
# |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- cause_of_infection_CC >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- cause_of_infection_TRAVEL >  0.50
# |   |   |   |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK <= 0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- cause_of_infection_NO KNOWN EPI LINK >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- cause_of_infection_MISSING INFORMATION >  0.50
# |   |   |   |--- gender_MALE <= 0.50
# |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- gender_MALE >  0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- class: 0
# |--- cause_of_infection_OB >  0.50
# |   |--- Resolved_yes <= 0.50
# |   |   |--- gender_MALE <= 0.50
# |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |--- class: 1
# |   |   |--- gender_MALE >  0.50
# |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- lockdown >  0.50
# |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |--- class: 0
# |   |--- Resolved_yes >  0.50
# |   |   |--- gender_MALE <= 0.50
# |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |--- gender_UNSPECIFIED <= 0.50
# |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender_UNSPECIFIED >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- lockdown >  0.50
# |   |   |   |   |--- gender_GENDER DIVERSE <= 0.50
# |   |   |   |   |   |--- gender_FEMALE <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender_FEMALE >  0.50
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- gender_GENDER DIVERSE >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- gender_MALE >  0.50
# |   |   |   |--- lockdown <= 0.50
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction <= 0.50
# |   |   |   |   |   |--- Parks Re-opened <= 0.50
# |   |   |   |   |   |   |--- Restart <= 0.50
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- reporting_phu_city_Ottawa >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Restart >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Parks Re-opened >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Gatineau-Ottawa Travel Restriction >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- lockdown >  0.50
# |   |   |   |   |--- reporting_phu_city_Toronto <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- reporting_phu_city_Toronto >  0.50
# |   |   |   |   |   |--- class: 1
