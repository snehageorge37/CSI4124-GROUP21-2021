# %%
import pandas as pd
import numpy as np

from datetime import datetime, timedelta

# %%
dailydata = pd.read_csv("conposcovidloc.csv")
dailydata.head()
# Out:
#    Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 0       1            2020-06-06         2020-06-12         2020-06-11
# 1       2            2020-05-03         2020-05-11         2020-05-11
# 2       3            2020-04-16         2020-04-19         2020-04-19
# 3       4            2020-04-07         2020-04-26         2020-04-26
# 4       5            2020-05-21         2020-05-22         2020-05-22
#
#   Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  Outcome1  \
# 0    2020-06-10       50s        FEMALE                   CC  Resolved
# 1    2020-05-10       70s          MALE                   OB     Fatal
# 2    2020-04-17       40s        FEMALE                   OB  Resolved
# 3    2020-04-21       60s          MALE                   CC  Resolved
# 4    2020-05-21       60s        FEMALE                   OB  Resolved
#
#   Outbreak_Related  Reporting_PHU_ID                    Reporting_PHU  \
# ...

# %%
dailydata.shape
# Out:
# (289621, 18)

# %%
removeCities = dailydata[(dailydata['Reporting_PHU_City'] != 'Toronto') & (dailydata['Reporting_PHU_City'] != 'Ottawa')].index
dailydata.drop(removeCities , inplace=True)

# %%
dailydata.head()
# Out:
#      Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 249     250            2020-04-28         2020-05-03         2020-05-03
# 258     259            2020-03-24         2020-03-25         2020-03-24
# 321     322            2020-04-17         2020-04-20         2020-04-20
# 325     326            2020-04-02         2020-04-06         2020-04-29
# 346     347            2020-04-10         2020-04-17         2020-04-11
#
#     Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  Outcome1  \
# 249    2020-04-30       40s        FEMALE                   OB  Resolved
# 258    2020-03-24       50s          MALE    NO KNOWN EPI LINK  Resolved
# 321    2020-04-19       30s        FEMALE                   OB  Resolved
# 325    2020-04-02       90+        FEMALE                   OB     Fatal
# 346    2020-04-10       80s        FEMALE                   OB  Resolved
#
#     Outbreak_Related  Reporting_PHU_ID          Reporting_PHU  \
# ...

# %%
dailydata.shape
# Out:
# (104872, 18)

# %%
removeDates = dailydata[(dailydata['Case_Reported_Date'] >= '2020-04-01') & (dailydata['Case_Reported_Date'] <= '2020-07-31')].index
dailydata.drop(removeDates , inplace=True)

# %%
dailydata.head()
# Out:
#       Row_ID Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 258      259            2020-03-24         2020-03-25         2020-03-24
# 5980    5981            2020-03-10         2020-03-16         2020-03-16
# 7344    7345            2020-03-23         2020-03-23         2021-02-16
# 7353    7354            2020-03-23         2020-03-24         2020-03-25
# 8095    8096            2020-03-21         2020-03-28         2020-03-28
#
#      Specimen_Date Age_Group Client_Gender Case_AcquisitionInfo  Outcome1  \
# 258     2020-03-24       50s          MALE    NO KNOWN EPI LINK  Resolved
# 5980    2020-03-14       20s          MALE               TRAVEL  Resolved
# 7344    2021-02-15       50s          MALE                   OB  Resolved
# 7353    2020-03-23       20s        FEMALE                   CC  Resolved
# 8095    2020-03-27       70s        FEMALE               TRAVEL  Resolved
#
#      Outbreak_Related  Reporting_PHU_ID          Reporting_PHU  \
# ...

# %%
dailydata.shape
# Out:
# (89461, 18)

# %%
dailydata = dailydata.drop(['Accurate_Episode_Date', 'Test_Reported_Date', 'Specimen_Date', 'Outcome1', 'Reporting_PHU_ID', 'Reporting_PHU', 'Reporting_PHU_Address', 'Reporting_PHU_City', 'Reporting_PHU_Postal_Code', 'Reporting_PHU_Website', 'Reporting_PHU_Latitude', 'Reporting_PHU_Longitude'], axis=1)

# %%
dailydata.head()
# Out:
#       Row_ID Case_Reported_Date Age_Group Client_Gender Case_AcquisitionInfo  \
# 258      259         2020-03-25       50s          MALE    NO KNOWN EPI LINK
# 5980    5981         2020-03-16       20s          MALE               TRAVEL
# 7344    7345         2020-03-23       50s          MALE                   OB
# 7353    7354         2020-03-24       20s        FEMALE                   CC
# 8095    8096         2020-03-28       70s        FEMALE               TRAVEL
#
#      Outbreak_Related
# 258               NaN
# 5980              NaN
# 7344              Yes
# 7353              NaN
# 8095              NaN

# %%
dailydata.columns
# Out:
# Index(['Individual_ID', 'Date', 'Age_Group', 'Gender', 'Cause_of_Infection',
#        'Outbreak_Related'],
#       dtype='object')

# %%
dailydata.rename(columns = {"Row_ID": "Individual_ID"}, inplace=True)
dailydata.rename(columns = {"Case_Reported_Date": "Date"}, inplace=True)
dailydata.rename(columns = {"Client_Gender": "Gender"}, inplace=True)
dailydata.rename(columns = {"Case_AcquisitionInfo": "Cause_of_Infection"}, inplace=True)

# %%
dailydata.columns
# Out:
# Index(['Individual_ID', 'Date', 'Age_Group', 'Gender', 'Cause_of_Infection',
#        'Outbreak_Related'],
#       dtype='object')

# %%
dailydata = dailydata[['Individual_ID', 'Age_Group', 'Gender', 'Cause_of_Infection',
       'Outbreak_Related', 'Date']]

# %%
dailydata.columns
# Out:
# Index(['Individual_ID', 'Age_Group', 'Gender', 'Cause_of_Infection',
#        'Outbreak_Related', 'Date'],
#       dtype='object')

# %%
dailydata.head()
# Out:
#       Individual_ID Age_Group  Gender Cause_of_Infection Outbreak_Related  \
# 258             259       50s    MALE  NO KNOWN EPI LINK              NaN
# 5980           5981       20s    MALE             TRAVEL              NaN
# 7344           7345       50s    MALE                 OB              Yes
# 7353           7354       20s  FEMALE                 CC              NaN
# 8095           8096       70s  FEMALE             TRAVEL              NaN
#
#             Date
# 258   2020-03-25
# 5980  2020-03-16
# 7344  2020-03-23
# 7353  2020-03-24
# 8095  2020-03-28

# %%
dailydata.to_csv("individual_dimension.csv",index=False)
